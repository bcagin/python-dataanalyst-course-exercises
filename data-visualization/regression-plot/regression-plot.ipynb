# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df_reg = pd.read_csv('scatter_plot_ii.csv')

# %%
df_reg
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
sns.set(rc = {'figure.figsize' : (9,6)})
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_reg,
           scatter_kws = {'color' : 'k'},
           line_kws = {'color' : 'red'})
plt.xlabel('Ad Expenditure in (000s $)')
plt.ylabel('Sales in (000s in Units)')
plt.title('Effect of Ad Expenditure on Sales', fontsize = 14, fontweight = 'bold')
plt.savefig('Effect of Ad Expenditure on Sales')
plt.show()
